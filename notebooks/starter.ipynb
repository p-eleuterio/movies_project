# %% [markdown]
# # Kueski Take-Home Starter\n\nOutline for EDA, feature engineering, and baseline model. Fill in each section as you work.

# %% [markdown]
# ## 0. Setup\
#
# Import libraries\n- Set paths and seed\n- Load raw CSVs from `data/raw`

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/movielens-20m-dataset/genome_scores.csv')

# %%
df.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %% [markdown]
# ## 1. Exploration (optional deliverable)\
#
# Basic stats for users, movies, ratings\n- Sparsity checks, time ranges

# %% [markdown]
# ## 2. Feature engineering
#
# Ideas to consider (keep only what you use):
# - User history: mean/median rating, count, recency-weighted mean
# - Movie signals: global mean rating, number of ratings, volatility (std)
# - User × genre affinity: merge movie genres and compute user-genre a|verage\n-
# - Tag relevance: aggregate genome scores per user/movie, top-N tags\n-
# - Time: days since last rating, rating day-of-week/month\n- Cold-start fallbacks (global priors)

# %% [markdown]
# ## 3. Modeling\n- Create binary label `is_high_rating = rating >= 4`\n- Train/validation split by time or user-based to avoid leakage\n- Try a fast baseline (e.g., Logistic Regression, LightGBM, RandomForest)\n- Evaluate with AUC/PR-AUC and calibration

# %% [markdown]
# ## 4. Feature importance & insights\n- Gain/SHAP for tree models; coefficients for linear models\n- Summarize top drivers and business takeaways

# %% [markdown]
# ## 5. Next steps\n- Ideas for productionization (feature freshness, monitoring)\n- Additional features to try
